# %% [markdown]
# # 05-2 Llama 모델로 텍스트 생성하기

# %% [markdown]
# <table align="left"><tr><td>
# <a href="https://colab.research.google.com/github/rickiepark/hm-dl/blob/main/05-2-llama2-keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="코랩에서 실행하기"/></a>
# </td></tr></table>

# %% [markdown]
# 코랩에서 이 노트북을 실행하려면 High-RAM CPU 런타임을 사용해야 합니다.

# %% [markdown]
# ## LlaMA-2 모델로 텍스트 생성하기

# %% [markdown]
# ** 라마-2, 라마-3 모델을 사용하려면 먼저 메타에 사용 허가를 얻어야 합니다. 자세한 내용은 도서를 참고하세요.**
#
# 캐글에서 라마-2 모델을 다운로드하려면 캐글 API 토큰을 생성하여 ~/.kaggle/ 디렉토리에 저장하세요.

# %%
# !mkdir ~/.kaggle/
# !mv kaggle.json ~/.kaggle/
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %% [markdown]
# ### Llama-2 모델로 텍스트 생성하기

# %%
import keras_nlp

# %%
# llama2 = keras_nlp.models.LlamaCausalLM.from_preset('llama2_7b_en')
llama2 = keras_nlp.models.LlamaCausalLM.from_preset('MLP-KTLim/llama-3-Korean-Bllossom-8B')
llama2.summary()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/http_resolver.py:198, in ModelHttpResolver._resolve.<locals>.<lambda>()
#     197 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 198 response = handle_call(lambda: api_client.models.model_api_client.download_model_instance_version(r), h)
#     199 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglesdk/models/services/model_api_service.py:116, in ModelApiClient.download_model_instance_version(self, request)
#     114   request = ApiDownloadModelInstanceVersionRequest()
# --> 116 return self._client.call("models.ModelApiService", "DownloadModelInstanceVersion", request, HttpRedirect)
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglesdk/kaggle_http_client.py:98, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      96 http_response = self._session.send(http_request, **settings)
# ---> 98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglesdk/kaggle_http_client.py:124, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     123     pass
# --> 124 http_response.raise_for_status()
#     125 # Allow client to check header content.
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/requests/models.py:1028, in Response.raise_for_status(self)
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/models.ModelApiService/DownloadModelInstanceVersion
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# File ~/hm-dl/.venv/lib/python3.10/site-packages/keras_hub/src/utils/preset_utils.py:155, in get_file(preset, path)
#     154 try:
# --> 155     return kagglehub.model_download(kaggle_handle, path)
#     156 except KaggleApiHTTPError as e:
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/models.py:38, in model_download(handle, path, force_download, output_dir)
#      37 logger.info(f"Downloading Model: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 38 path, _ = registry.model_resolver(
#      39     h,
#      40     path,
#      41     force_download=force_download,
#      42     output_dir=output_dir,
#      43 )
#      44 return path
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      27 if impl.is_supported(*args, **kwargs):
# ---> 28     return impl(*args, **kwargs)
#      29 else:
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      23 """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25 Args:
#    (...)
#      33     Some cases where version number might be missing: Competition datasource, API-based models.
#      34 """
# ---> 35 path, version = self._resolve(
#      36     handle,
#      37     path,
#      38     force_download=force_download,
#      39     output_dir=output_dir,
#      40 )
#      42 # Note handles are immutable, so _resolve() could not have altered our reference
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/http_resolver.py:198, in ModelHttpResolver._resolve(self, h, path, force_download, output_dir)
#     197 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 198 response = handle_call(lambda: api_client.models.model_api_client.download_model_instance_version(r), h)
#     199 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/kagglehub/exceptions.py:107, in handle_call(fn, resource_handle)
#     106 # Default handling
# --> 107 raise KaggleApiHTTPError(message, response=e.response) from e
#
# KaggleApiHTTPError: 403 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/models/keras/llama2/keras/llama2_7b_en/3. Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 llama2 = keras_nlp.models.LlamaCausalLM.from_preset('llama2_7b_en')
#       2 llama2.summary()
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/keras_hub/src/models/task.py:185, in Task.from_preset(cls, preset, load_weights, **kwargs)
#     178 if cls == Task:
#     179     raise ValueError(
#     180         "Do not call `Task.from_preset()` directly. Instead call a "
#     181         "particular task class, e.g. "
#     182         "`keras_hub.models.TextClassifier.from_preset()`."
#     183     )
# --> 185 loader = get_preset_loader(preset)
#     186 backbone_cls = loader.check_backbone_class()
#     187 # Detect the correct subclass if we need to.
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/keras_hub/src/utils/preset_utils.py:541, in get_preset_loader(preset)
#     540 def get_preset_loader(preset):
# --> 541     if not check_file_exists(preset, CONFIG_FILE):
#     542         raise ValueError(
#     543             f"Preset {preset} has no {CONFIG_FILE}. Make sure the URI or "
#     544             "directory you are trying to load is a valid KerasHub preset and "
#     545             "and that you have permissions to read/download from this location."
#     546         )
#     547     # We currently assume all formats we support have a `config.json`, this is
#     548     # true, for Keras, Transformers, and timm. We infer the on disk format by
#     549     # inspecting the `config.json` file.
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/keras_hub/src/utils/preset_utils.py:300, in check_file_exists(preset, path)
#     298 def check_file_exists(preset, path):
#     299     try:
# --> 300         get_file(preset, path)
#     301     except FileNotFoundError:
#     302         return False
#
# File ~/hm-dl/.venv/lib/python3.10/site-packages/keras_hub/src/utils/preset_utils.py:163, in get_file(preset, path)
#     159         raise FileNotFoundError(
#     160             f"`{path}` doesn't exist in preset directory `{preset}`."
#     161         )
#     162     else:
# --> 163         raise ValueError(message)
#     164 except ValueError as e:
#     165     message = str(e)
#
# ValueError: 403 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/models/keras/llama2/keras/llama2_7b_en/3. Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.

# %%
sampler = keras_nlp.samplers.TopPSampler(p=0.8, seed=42)
llama2.compile(sampler=sampler)
llama2.generate('stay hungry, stay', max_length=20)
# Out:
# 'stay hungry, stay weird. It’s kind of what our philosophy is.\nWe'

# %% [markdown]
# ### 텍스트 전처리하기 - 센텐스피스 토크나이저

# %%
llama_tokenizer = keras_nlp.models.LlamaTokenizer.from_preset('llama2_7b_en')

# %%
token_ids = llama_tokenizer.tokenize('stay hungry, stay')
token_ids
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 7952,  9074, 14793, 29892,  7952], dtype=int32)>

# %%
for ids in token_ids:
    print(llama_tokenizer.id_to_token(ids), end=' ')
# Out:
# ▁stay ▁hun gry , ▁stay

# %%
llama_tokenizer.tokenize('Hello hello')
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([15043, 22172], dtype=int32)>

# %%
llama_tokenizer.detokenize(token_ids)
# Out:
# 'stay hungry, stay'
